# %%
#reproducability
from numpy.random import seed
seed(1)
import tensorflow as tf
tf.random.set_seed(1)

import numpy as np
from bayes_opt import BayesianOptimization
from bayes_opt.logger import JSONLogger
from bayes_opt.event import Events
from bayes_opt.util import load_logs
import os
import glob
import pandas as pd
import keras as ks
import datetime
from scipy import stats
from matplotlib import pyplot
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

gpus = tf.config.experimental.list_physical_devices('GPU')

nl=np.array([0,130,234,330,413,492,564,626,686,742,826,898,964,1020,1075,1122,1166,1208,1248])
# Out:
# Using TensorFlow backend.

# %%
def load_Data(ns):    
    data_dir ='D:\\keras\\conduitflow'
    fname = os.path.join(data_dir, 'BTCdata_b+c.csv')

    f = open(fname)
    data = f.read()
    f.close()

    lines = data.split('\n')##以\n为分隔符，分割字符串data，形成字符串列表lines
    header = lines[0].split(',')##lines[0]为字符串，header为字符串列表
    lines = lines[1:-1]##提取字符串列表的第2至最后一个元素，形成新的列表
    
    float_data = np.zeros((len(lines), len(header)))##(1179,3)数组,元素为0
    for i, line in enumerate(lines):
    ## print(i) ##i=0时，对应line为lines的第一行
        values = [float(x) for x in line.split(',')]
        float_data[i, :] = values
    ##print(float_data[0, :])
    
    # inputs
    X_test=float_data[nl[ns-1]:nl[ns],0:3]##(55,2)  Q=0.1293L/s,c5的数据作测试样本，前两列为输入
    Y_test=float_data[nl[ns-1]:nl[ns],-1]##(55,)Q=0.1293L/s,c5的数据作测试样本，最后一列为浓度输出
    data=np.concatenate(
        [float_data[:nl[ns-1]],
         float_data[nl[ns]:]],
        axis=0)##(450,3) 剩下的450个样本做训练和验证样本
    np.random.shuffle(data)##打乱数据
    Train_data=data[:,0:3]##(450,2)#使用打乱后的450个样本作为训练和验证数据
    Train_targets=data[:,-1]##(450,)

    #scale data
    mean = Train_data.mean(axis=0)
    Train_data -= mean
    std = Train_data.std(axis=0)
    Train_data /= std

    X_test -= mean
    X_test /= std

    X_train = Train_data[0:round(0.8 * len(Train_data))]
    Y_train = Train_targets[0:round(0.8 * len(Train_targets))]
    X_stop = Train_data[round(0.8 * len(Train_data)):round(0.9 * len(Train_data))]
    Y_stop = Train_targets[round(0.8 * len(Train_targets)):round(0.9 * len(Train_targets))]
    X_opt=Train_data[round(0.9 * len(Train_data)):]
    Y_opt=Train_targets[round(0.9 * len(Train_targets)):]
    
    
    return X_train,Y_train,X_stop,Y_stop, X_opt,Y_opt,X_test,Y_test

# %%
def build_model(ini,GLOBAL_SETTINGS,X_train, Y_train,X_stop, Y_stop):
    # define model
    seed(ini)
    tf.random.set_seed(ini)
    model = ks.models.Sequential()
    model.add(ks.layers.Dense(GLOBAL_SETTINGS["hidden_size"], activation='relu',
                           input_shape=(X_train.shape[1],),name="dense_1"))
    model.add(ks.layers.Dense(GLOBAL_SETTINGS["hidden_size"], activation='relu',name="dense_2"))
    model.add(ks.layers.Dense(1,name="dense_3"))
    
    #optimizer = ks.optimizers.Adam(lr=GLOBAL_SETTINGS["learning_rate"], epsilon=10E-3,
                                   #clipnorm=GLOBAL_SETTINGS["clip_norm"], clipvalue=GLOBAL_SETTINGS["clip_value"])
    
    model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])

    # early stopping
    es = ks.callbacks.EarlyStopping(monitor='val_loss', mode='min', verbose=0, patience=50)
    
    model.fit(X_train, Y_train, validation_data=(X_stop, Y_stop), epochs=GLOBAL_SETTINGS["epochs"], verbose=0,
                        batch_size=GLOBAL_SETTINGS["batch_size"], callbacks=[es])
    
    return model

# %%
def bayesOpt_function(hiddensize, batchsize):
    hiddensize_int = int(hiddensize)
    batchsize_int = int(batchsize)

    return bayesOpt_function_with_discrete_params(hiddensize_int, batchsize_int)

# %%
def bayesOpt_function_with_discrete_params(hiddensize_int, batchsize_int):
    
    assert type(hiddensize_int) == int
    assert type(batchsize_int) == int
    #[...]
    
    # fixed settings for all experiments
    GLOBAL_SETTINGS = {
        'batch_size': batchsize_int,
        'clip_norm': True,
        'clip_value': 1,
        'dropout': 0,
        'epochs': 1000,
        'hidden_size': hiddensize_int,
        'learning_rate': 1e-3
    }


    #build and train model with idifferent initializations
    inimax = 5
    optresults_members = np.zeros((len(X_opt), inimax))
    #print(X_opt)#(n,2)
    #print(Y_opt)#(n,)
    for ini in range(inimax):
        print("BayesOpt-Iteration {} - ini-Ensemblemember {}".format(len(optimizer.res)+1, ini+1))
        
        # f = open('log_full.txt', "a")
        # print("BayesOpt-Iteration {} - ini-Ensemblemember {}".format(len(optimizer.res)+1, ini+1), file = f)
        # f.close()
        
        model = build_model(ini,GLOBAL_SETTINGS,X_train, Y_train, X_stop, Y_stop)  
        opt_sim= model.predict(X_opt)#(n,1)
        #opt_sim = scaler_gwl.inverse_transform(opt_sim_n)
        #optresults_members[:, ini] = opt_sim
        optresults_members[:, ini] = opt_sim.reshape(-1,)#(n,) 
    
    opt_sim_median = np.median(optresults_members,axis = 1)#(n,)    
    #sim = np.asarray(opt_sim_median.reshape(-1,1))#(n,1)
    #obs = np.asarray(Y_opt.reshape(-1,1))#(n,1)
    #err = sim-obs
    #meanTrainingGWL = np.mean(np.asarray(TrainingData['GWL']))
    #meanStopGWL = np.mean(np.asarray(StopData['GWL']))
    #err_nash = obs - np.mean([meanTrainingGWL, meanStopGWL])
    #r = stats.linregress(sim[:,0], obs[:,0])
    r = stats.linregress(Y_opt, opt_sim_median)
    
    print("total elapsed time = {}".format(datetime.datetime.now()-time1))
    print("(pp) elapsed time = {}".format(datetime.datetime.now()-time_single))
    # f = open('log_full.txt', "a")
    # print("elapsed time = {}".format(datetime.datetime.now()-time1), file = f)
    # f.close()
    
    #return (1 - ((np.sum(err ** 2)) / (np.sum((err_nash) ** 2)))) + r.rvalue ** 2 #NSE+R²: (max = 2)
    return  (r2_score(Y_opt,opt_sim_median)+r.rvalue ** 2)

# %%
def simulate_testset(hiddensize_int, batchsize_int):
    
    GLOBAL_SETTINGS = {
        'batch_size': batchsize_int,
        'clip_norm': True,
        'clip_value': 1,
        'dropout': 0,
        'epochs': 1000,
        'hidden_size': hiddensize_int,
        'learning_rate': 1e-3
    }

    #build and train model with idifferent initializations
    inimax = 20
    testresults_members = np.zeros((len(X_test), inimax))
    for ini in range(inimax):
        model = build_model(ini,GLOBAL_SETTINGS,X_train, Y_train, X_stop, Y_stop)  
        test_sim= model.predict(X_test)#(n,1)
        #test_sim = scaler_gwl.inverse_transform(test_sim_n)
        testresults_members[:, ini] = test_sim.reshape(-1,)#(n,) 
        #testresults_members的shape为(79,10)
    
    test_sim_median = np.median(testresults_members,axis = 1)#（n,）   
    
    #introduce GWL t-1 as additional Input (nalso needed for PI calculation)
    #GWData_shift1 = pd.DataFrame(data['GWL'])
    #GWData_shift1.index = GWData_shift1.index.shift(periods = 7, freq = 'D')
    #GWData_shift1.rename(columns={"GWL": "GWLt-1"},inplace=True)
    #PIData = GWData_shift1[(GWData_shift1.index >= GLOBAL_SETTINGS["test_start"]) & (GWData_shift1.index <= GLOBAL_SETTINGS["test_end"])]
    
    # get scores

    r = stats.linregress(Y_test, test_sim_median)#stats.linregress(a, b)和stats.linregress(b, a)结果相同
    R2 = r.rvalue ** 2
    NSE = r2_score(Y_test,test_sim_median)#sklearn.metrics.r2_score(y_true, y_pred, *, sample_weight=None, multioutput='uniform_average')
    sim = np.asarray(test_sim_median.reshape(-1,1))#(n,1)
    #obs = np.asarray(scaler_gwl.inverse_transform(Y_test.reshape(-1,1)))
    obs = np.asarray(Y_test.reshape(-1,1))#(n,1)
    err = sim-obs#(n,1)
    Bias = np.mean(err)
    RMSE =  np.sqrt(np.mean(err ** 2))
    
    ##err_rel = (sim-obs)/(np.max(data['GWL'])-np.min(data['GWL']))
    #err_nash = obs - np.mean(np.asarray(data['GWL'][(data.index < GLOBAL_SETTINGS["test_start"])]))错误
    #err_nash = obs - np.mean(np.asarray(data['GWL'][(data.index >= GLOBAL_SETTINGS["test_start"]) & (data.index <= GLOBAL_SETTINGS["test_end"])]))
    #err_PI = obs-obs_PI
    #r = stats.linregress(sim[:,0], obs[:,0])
    #rRMSE = np.sqrt(np.mean(err_rel ** 2)) * 100
    #rBias = np.mean(err_rel) * 100
    #PI = 1 - ((np.sum(err ** 2)) / (np.sum((err_PI) ** 2)))
    scores = pd.DataFrame(np.array([[NSE, R2, RMSE, Bias]]),
                   columns=['NSE','R2','RMSE','Bias'])
    print(scores)

    errors = np.zeros((inimax,4))
    errors[:] = np.nan
    for i in range(inimax):
        sim = np.asarray(testresults_members[:,i].reshape(-1,1))#(n,1)
        # obs = np.asarray(scaler_gwl.inverse_transform(Y_test.reshape(-1,1)))
        err = sim-obs
        #err_rel = (sim-obs)/(np.max(data['GWL'])-np.min(data['GWL']))
        # err_nash = obs - np.mean(np.asarray(data['GWL'][(data.index < GLOBAL_SETTINGS["test_start"])]))错误
        #err_nash = obs - np.mean(np.asarray(data['GWL'][(data.index >= GLOBAL_SETTINGS["test_start"]) & (data.index <= GLOBAL_SETTINGS["test_end"])]))
        errors[i,0] = r2_score(Y_test,testresults_members[:,i])
        r = stats.linregress(sim[:,0], obs[:,0])
        errors[i,1] = r.rvalue ** 2
        errors[i,2] =  np.sqrt(np.mean(err ** 2))
        errors[i,3] = np.mean(err)
    
    sim = np.asarray(test_sim_median.reshape(-1,1))#median simulation (n,1)
    return scores, sim, obs, inimax, testresults_members, errors

# %%
class newJSONLogger(JSONLogger) :

      def __init__(self, path):
            self._path=None
            super(JSONLogger, self).__init__()
            self._path = path if path[-5:] == ".json" else path + ".json"

# %%
with tf.device("/gpu:0"): #type cpu to use cpu instead of gpu
    
    time1 = datetime.datetime.now()
    basedir = './'
    os.chdir(basedir)
    
    #for pp in range(0,17): #loop over all wells
    
    time_single = datetime.datetime.now()
    seed(1)
    tf.random.set_seed(1)
    
    ## load data
    X_train,Y_train,X_stop,Y_stop, X_opt,Y_opt,X_test,Y_test=load_Data(14)
    print(X_test)
    print(Y_test)
# Out:
# [[ 1.28266629  0.28481246 -1.01943545]
#  [ 1.28266629  0.28481246 -1.00212319]
#  [ 1.28266629  0.28481246 -0.98481093]
#  [ 1.28266629  0.28481246 -0.96749866]
#  [ 1.28266629  0.28481246 -0.9501864 ]
#  [ 1.28266629  0.28481246 -0.93287414]
#  [ 1.28266629  0.28481246 -0.91556187]
#  [ 1.28266629  0.28481246 -0.89824961]
#  [ 1.28266629  0.28481246 -0.88093735]
#  [ 1.28266629  0.28481246 -0.86362508]
#  [ 1.28266629  0.28481246 -0.84631282]
#  [ 1.28266629  0.28481246 -0.82900056]
#  [ 1.28266629  0.28481246 -0.81168829]
#  [ 1.28266629  0.28481246 -0.79437603]
#  [ 1.28266629  0.28481246 -0.77706377]
#  [ 1.28266629  0.28481246 -0.7597515 ]
#  [ 1.28266629  0.28481246 -0.74243924]
#  [ 1.28266629  0.28481246 -0.72512698]
#  [ 1.28266629  0.28481246 -0.70781471]
#  [ 1.28266629  0.28481246 -0.69050245]
#  [ 1.28266629  0.28481246 -0.67319019]
#  [ 1.28266629  0.28481246 -0.65587792]
#  [ 1.28266629  0.28481246 -0.63856566]
#  [ 1.28266629  0.28481246 -0.6212534 ]
#  [ 1.28266629  0.28481246 -0.60394113]
#  [ 1.28266629  0.28481246 -0.58662887]
#  [ 1.28266629  0.28481246 -0.56931661]
#  [ 1.28266629  0.28481246 -0.55200434]
#  [ 1.28266629  0.28481246 -0.53469208]
#  [ 1.28266629  0.28481246 -0.51737982]
#  [ 1.28266629  0.28481246 -0.50006755]
#  [ 1.28266629  0.28481246 -0.48275529]
#  [ 1.28266629  0.28481246 -0.46544303]
#  [ 1.28266629  0.28481246 -0.44813076]
#  [ 1.28266629  0.28481246 -0.4308185 ]
#  [ 1.28266629  0.28481246 -0.41350624]
#  [ 1.28266629  0.28481246 -0.39619397]
#  [ 1.28266629  0.28481246 -0.37888171]
#  [ 1.28266629  0.28481246 -0.36156945]
#  [ 1.28266629  0.28481246 -0.34425718]
#  [ 1.28266629  0.28481246 -0.32694492]
#  [ 1.28266629  0.28481246 -0.30963266]
#  [ 1.28266629  0.28481246 -0.2923204 ]
#  [ 1.28266629  0.28481246 -0.27500813]
#  [ 1.28266629  0.28481246 -0.25769587]
#  [ 1.28266629  0.28481246 -0.24038361]
#  [ 1.28266629  0.28481246 -0.22307134]
#  [ 1.28266629  0.28481246 -0.20575908]
#  [ 1.28266629  0.28481246 -0.18844682]
#  [ 1.28266629  0.28481246 -0.17113455]
#  [ 1.28266629  0.28481246 -0.15382229]
#  [ 1.28266629  0.28481246 -0.13651003]
#  [ 1.28266629  0.28481246 -0.11919776]
#  [ 1.28266629  0.28481246 -0.1018855 ]
#  [ 1.28266629  0.28481246 -0.08457324]]
# [0.000489 0.000489 0.00201  0.00505  0.0111   0.0223   0.0385   0.0567
#  0.0764   0.0942   0.107    0.113    0.115    0.112    0.107    0.0992
#  0.0901   0.0805   0.0709   0.0623   0.0542   0.0471   0.0415   0.0364
#  0.0314   0.0273   0.0243   0.0207   0.0182   0.0157   0.0142   0.0121
#  0.0106   0.0091   0.00808  0.00707  0.00656  0.00555  0.00505  0.00454
#  0.00403  0.00353  0.00302  0.00251  0.00251  0.00201  0.00201  0.0015
#  0.0015   0.0015   0.000995 0.000995 0.000995 0.000995 0.000489]

# %%
# Bounded region of parameter space
    pbounds = {'hiddensize': (1, 64),
                'batchsize': (16, 256)} #constrained optimization technique, so you must specify the minimum and maximum values that can be probed for each parameter
        
    optimizer = BayesianOptimization(
                f= bayesOpt_function, #function that is optimized
                pbounds=pbounds, #opt.-range of parameters
                random_state=1, 
                verbose = 0 # verbose = 1 prints only when a maximum is observed, verbose = 0 is silent, verbose = 2 prints everything
                )

# %%
#load existing optimizer
    log_already_available = 0
    if os.path.isfile("./logs_bc_c5"+".json"):
        load_logs(optimizer, logs=["./logs_bc_c5"+".json"]);
        print("\nExisting optimizer is already aware of {} points.".format(len(optimizer.space)))
        log_already_available = 1
            
    # Saving progress
    logger = newJSONLogger(path="./logs_bc_c5"+".json")
    optimizer.subscribe(Events.OPTIMIZATION_STEP, logger)

# %%
# random exploration as a start
    f = open('./timelog_bc_c5'+'.txt', "w")
    print("Starttime of first iteration: {}\n".format(datetime.datetime.now()), file = f)#this is not looged in json file

# %%
    if log_already_available == 0:
            optimizer.maximize(
                init_points=25, #steps of random exploration (random starting points before bayesopt(?))
                n_iter=0, # steps of bayesian optimization
                acq="ei",# ei  = expected improvmenet (probably the most common acquisition function) 
                xi=0.05  #  Prefer exploitation (xi=0.0) / Prefer exploration (xi=0.1)
                )
        
    # optimize while improvement during last 10 steps!
    current_step = len(optimizer.res)
    beststep = False
    step = -1
    while not beststep:
        step = step + 1
        beststep = optimizer.res[step] == optimizer.max #search for best iteration step
    while current_step < 50: #below < 50 iterations, no termination
            current_step = len(optimizer.res)
            beststep = False
            step = -1
            while not beststep:
                step = step + 1
                beststep = optimizer.res[step] == optimizer.max
            print("\nbeststep {}, current step {}".format(step+1, current_step+1))
            optimizer.maximize(
                init_points=0, #steps of random exploration 
                n_iter=1, # steps of bayesian optimization
                acq="ei",# ei  = expected improvmenet (probably the most common acquisition function) 
                xi=0.05  #  Prefer exploitation (xi=0.0) / Prefer exploration (xi=0.1)
                )
                
    while (step + 20 > current_step and current_step < 150): # termination after 50 steps or after 10 steps without improvement
            current_step = len(optimizer.res)
            beststep = False
            step = -1
            while not beststep:
                step = step + 1
                beststep = optimizer.res[step] == optimizer.max
                    

            print("\nbeststep {}, current step {}".format(step+1, current_step+1))
            optimizer.maximize(
                init_points=0, #steps of random exploration
                n_iter=1, # steps of bayesian optimization
                acq="ei",# ei  = expected improvmenet (probably the most common acquisition function) 
                xi=0.05  #  Prefer exploitation (xi=0.0) / Prefer exploration (xi=0.1)
                )
            
    print("\nBEST:\t{}".format(optimizer.max))
    # for i, res in enumerate(optimizer.res):
    #     print("Iteration {}: \t{}".format(i+1, res))
            
    
        
    #best values from optimizer
    hiddensize_int = int(optimizer.max.get("params").get("hiddensize"))
    batchsize_int = int(optimizer.max.get("params").get("batchsize"))
# Out:
# BayesOpt-Iteration 1 - ini-Ensemblemember 1
# BayesOpt-Iteration 1 - ini-Ensemblemember 2
# BayesOpt-Iteration 1 - ini-Ensemblemember 3
# BayesOpt-Iteration 1 - ini-Ensemblemember 4
# BayesOpt-Iteration 1 - ini-Ensemblemember 5
# total elapsed time = 0:01:06.355461
# (pp) elapsed time = 0:01:06.355461
# BayesOpt-Iteration 2 - ini-Ensemblemember 1
# BayesOpt-Iteration 2 - ini-Ensemblemember 2
# BayesOpt-Iteration 2 - ini-Ensemblemember 3
# BayesOpt-Iteration 2 - ini-Ensemblemember 4
# BayesOpt-Iteration 2 - ini-Ensemblemember 5
# total elapsed time = 0:05:12.036538
# (pp) elapsed time = 0:05:12.036538
# BayesOpt-Iteration 3 - ini-Ensemblemember 1
# BayesOpt-Iteration 3 - ini-Ensemblemember 2
# BayesOpt-Iteration 3 - ini-Ensemblemember 3
# BayesOpt-Iteration 3 - ini-Ensemblemember 4
# BayesOpt-Iteration 3 - ini-Ensemblemember 5
# total elapsed time = 0:06:56.142709
# (pp) elapsed time = 0:06:56.143738
# BayesOpt-Iteration 4 - ini-Ensemblemember 1
# BayesOpt-Iteration 4 - ini-Ensemblemember 2
# BayesOpt-Iteration 4 - ini-Ensemblemember 3
# BayesOpt-Iteration 4 - ini-Ensemblemember 4
# BayesOpt-Iteration 4 - ini-Ensemblemember 5
# total elapsed time = 0:08:41.694857
# (pp) elapsed time = 0:08:41.694857
# BayesOpt-Iteration 5 - ini-Ensemblemember 1
# BayesOpt-Iteration 5 - ini-Ensemblemember 2
# BayesOpt-Iteration 5 - ini-Ensemblemember 3
# BayesOpt-Iteration 5 - ini-Ensemblemember 4
# BayesOpt-Iteration 5 - ini-Ensemblemember 5
# total elapsed time = 0:10:01.573507
# (pp) elapsed time = 0:10:01.573507
# BayesOpt-Iteration 6 - ini-Ensemblemember 1
# BayesOpt-Iteration 6 - ini-Ensemblemember 2
# BayesOpt-Iteration 6 - ini-Ensemblemember 3
# BayesOpt-Iteration 6 - ini-Ensemblemember 4
# BayesOpt-Iteration 6 - ini-Ensemblemember 5
# total elapsed time = 0:11:00.406313
# (pp) elapsed time = 0:11:00.406313
# BayesOpt-Iteration 7 - ini-Ensemblemember 1
# BayesOpt-Iteration 7 - ini-Ensemblemember 2
# BayesOpt-Iteration 7 - ini-Ensemblemember 3
# BayesOpt-Iteration 7 - ini-Ensemblemember 4
# BayesOpt-Iteration 7 - ini-Ensemblemember 5
# total elapsed time = 0:12:23.707746
# (pp) elapsed time = 0:12:23.708770
# BayesOpt-Iteration 8 - ini-Ensemblemember 1
# BayesOpt-Iteration 8 - ini-Ensemblemember 2
# BayesOpt-Iteration 8 - ini-Ensemblemember 3
# BayesOpt-Iteration 8 - ini-Ensemblemember 4
# BayesOpt-Iteration 8 - ini-Ensemblemember 5
# total elapsed time = 0:15:14.376814
# (pp) elapsed time = 0:15:14.376814
# BayesOpt-Iteration 9 - ini-Ensemblemember 1
# BayesOpt-Iteration 9 - ini-Ensemblemember 2
# BayesOpt-Iteration 9 - ini-Ensemblemember 3
# BayesOpt-Iteration 9 - ini-Ensemblemember 4
# BayesOpt-Iteration 9 - ini-Ensemblemember 5
# total elapsed time = 0:16:22.322903
# (pp) elapsed time = 0:16:22.322903
# BayesOpt-Iteration 10 - ini-Ensemblemember 1
# BayesOpt-Iteration 10 - ini-Ensemblemember 2
# BayesOpt-Iteration 10 - ini-Ensemblemember 3
# BayesOpt-Iteration 10 - ini-Ensemblemember 4
# BayesOpt-Iteration 10 - ini-Ensemblemember 5
# total elapsed time = 0:18:22.106785
# (pp) elapsed time = 0:18:22.106785
# BayesOpt-Iteration 11 - ini-Ensemblemember 1
# BayesOpt-Iteration 11 - ini-Ensemblemember 2
# BayesOpt-Iteration 11 - ini-Ensemblemember 3
# BayesOpt-Iteration 11 - ini-Ensemblemember 4
# BayesOpt-Iteration 11 - ini-Ensemblemember 5
# total elapsed time = 0:19:06.726928
# (pp) elapsed time = 0:19:06.727952
# BayesOpt-Iteration 12 - ini-Ensemblemember 1
# BayesOpt-Iteration 12 - ini-Ensemblemember 2
# BayesOpt-Iteration 12 - ini-Ensemblemember 3
# BayesOpt-Iteration 12 - ini-Ensemblemember 4
# BayesOpt-Iteration 12 - ini-Ensemblemember 5
# total elapsed time = 0:20:20.227676
# (pp) elapsed time = 0:20:20.227676
# BayesOpt-Iteration 13 - ini-Ensemblemember 1
# BayesOpt-Iteration 13 - ini-Ensemblemember 2
# BayesOpt-Iteration 13 - ini-Ensemblemember 3
# BayesOpt-Iteration 13 - ini-Ensemblemember 4
# BayesOpt-Iteration 13 - ini-Ensemblemember 5
# total elapsed time = 0:20:39.495027
# (pp) elapsed time = 0:20:39.495027
# BayesOpt-Iteration 14 - ini-Ensemblemember 1
# BayesOpt-Iteration 14 - ini-Ensemblemember 2
# BayesOpt-Iteration 14 - ini-Ensemblemember 3
# BayesOpt-Iteration 14 - ini-Ensemblemember 4
# BayesOpt-Iteration 14 - ini-Ensemblemember 5
# total elapsed time = 0:22:03.455453
# (pp) elapsed time = 0:22:03.456450
# BayesOpt-Iteration 15 - ini-Ensemblemember 1
# BayesOpt-Iteration 15 - ini-Ensemblemember 2
# BayesOpt-Iteration 15 - ini-Ensemblemember 3
# BayesOpt-Iteration 15 - ini-Ensemblemember 4
# BayesOpt-Iteration 15 - ini-Ensemblemember 5
# total elapsed time = 0:23:15.028489
# (pp) elapsed time = 0:23:15.028489
# BayesOpt-Iteration 16 - ini-Ensemblemember 1
# BayesOpt-Iteration 16 - ini-Ensemblemember 2
# BayesOpt-Iteration 16 - ini-Ensemblemember 3
# BayesOpt-Iteration 16 - ini-Ensemblemember 4
# BayesOpt-Iteration 16 - ini-Ensemblemember 5
# total elapsed time = 0:25:49.033400
# (pp) elapsed time = 0:25:49.033400
# BayesOpt-Iteration 17 - ini-Ensemblemember 1
# BayesOpt-Iteration 17 - ini-Ensemblemember 2
# BayesOpt-Iteration 17 - ini-Ensemblemember 3
# BayesOpt-Iteration 17 - ini-Ensemblemember 4
# BayesOpt-Iteration 17 - ini-Ensemblemember 5
# total elapsed time = 0:26:16.710972
# (pp) elapsed time = 0:26:16.710972
# BayesOpt-Iteration 18 - ini-Ensemblemember 1
# BayesOpt-Iteration 18 - ini-Ensemblemember 2
# BayesOpt-Iteration 18 - ini-Ensemblemember 3
# BayesOpt-Iteration 18 - ini-Ensemblemember 4
# BayesOpt-Iteration 18 - ini-Ensemblemember 5
# total elapsed time = 0:26:53.775548
# (pp) elapsed time = 0:26:53.775548
# BayesOpt-Iteration 19 - ini-Ensemblemember 1
# BayesOpt-Iteration 19 - ini-Ensemblemember 2
# BayesOpt-Iteration 19 - ini-Ensemblemember 3
# BayesOpt-Iteration 19 - ini-Ensemblemember 4
# BayesOpt-Iteration 19 - ini-Ensemblemember 5
# total elapsed time = 0:27:22.868141
# (pp) elapsed time = 0:27:22.868141
# BayesOpt-Iteration 20 - ini-Ensemblemember 1
# BayesOpt-Iteration 20 - ini-Ensemblemember 2
# BayesOpt-Iteration 20 - ini-Ensemblemember 3
# BayesOpt-Iteration 20 - ini-Ensemblemember 4
# BayesOpt-Iteration 20 - ini-Ensemblemember 5
# total elapsed time = 0:31:50.028851
# (pp) elapsed time = 0:31:50.028851
# BayesOpt-Iteration 21 - ini-Ensemblemember 1
# BayesOpt-Iteration 21 - ini-Ensemblemember 2
# BayesOpt-Iteration 21 - ini-Ensemblemember 3
# BayesOpt-Iteration 21 - ini-Ensemblemember 4
# BayesOpt-Iteration 21 - ini-Ensemblemember 5
# total elapsed time = 0:32:00.790232
# (pp) elapsed time = 0:32:00.790232
# BayesOpt-Iteration 22 - ini-Ensemblemember 1
# BayesOpt-Iteration 22 - ini-Ensemblemember 2
# BayesOpt-Iteration 22 - ini-Ensemblemember 3
# BayesOpt-Iteration 22 - ini-Ensemblemember 4
# BayesOpt-Iteration 22 - ini-Ensemblemember 5
# total elapsed time = 0:33:21.793405
# (pp) elapsed time = 0:33:21.793405
# BayesOpt-Iteration 23 - ini-Ensemblemember 1
# BayesOpt-Iteration 23 - ini-Ensemblemember 2
# BayesOpt-Iteration 23 - ini-Ensemblemember 3
# BayesOpt-Iteration 23 - ini-Ensemblemember 4
# BayesOpt-Iteration 23 - ini-Ensemblemember 5
# total elapsed time = 0:36:03.377349
# (pp) elapsed time = 0:36:03.377349
# BayesOpt-Iteration 24 - ini-Ensemblemember 1
# BayesOpt-Iteration 24 - ini-Ensemblemember 2
# BayesOpt-Iteration 24 - ini-Ensemblemember 3
# BayesOpt-Iteration 24 - ini-Ensemblemember 4
# BayesOpt-Iteration 24 - ini-Ensemblemember 5
# total elapsed time = 0:36:20.375333
# (pp) elapsed time = 0:36:20.375333
# BayesOpt-Iteration 25 - ini-Ensemblemember 1
# BayesOpt-Iteration 25 - ini-Ensemblemember 2
# BayesOpt-Iteration 25 - ini-Ensemblemember 3
# BayesOpt-Iteration 25 - ini-Ensemblemember 4
# BayesOpt-Iteration 25 - ini-Ensemblemember 5
# total elapsed time = 0:37:27.606488
# (pp) elapsed time = 0:37:27.606488
#
# beststep 20, current step 26
# BayesOpt-Iteration 26 - ini-Ensemblemember 1
# BayesOpt-Iteration 26 - ini-Ensemblemember 2
# BayesOpt-Iteration 26 - ini-Ensemblemember 3
# BayesOpt-Iteration 26 - ini-Ensemblemember 4
# BayesOpt-Iteration 26 - ini-Ensemblemember 5
# total elapsed time = 0:38:36.955233
# (pp) elapsed time = 0:38:36.955233
#
# beststep 20, current step 27
# BayesOpt-Iteration 27 - ini-Ensemblemember 1
# BayesOpt-Iteration 27 - ini-Ensemblemember 2
# BayesOpt-Iteration 27 - ini-Ensemblemember 3
# BayesOpt-Iteration 27 - ini-Ensemblemember 4
# BayesOpt-Iteration 27 - ini-Ensemblemember 5
# total elapsed time = 0:40:38.357508
# (pp) elapsed time = 0:40:38.357508
#
# beststep 20, current step 28
# BayesOpt-Iteration 28 - ini-Ensemblemember 1
# BayesOpt-Iteration 28 - ini-Ensemblemember 2
# BayesOpt-Iteration 28 - ini-Ensemblemember 3
# BayesOpt-Iteration 28 - ini-Ensemblemember 4
# BayesOpt-Iteration 28 - ini-Ensemblemember 5
# total elapsed time = 0:42:31.794272
# (pp) elapsed time = 0:42:31.794272
#
# beststep 20, current step 29
# BayesOpt-Iteration 29 - ini-Ensemblemember 1
# BayesOpt-Iteration 29 - ini-Ensemblemember 2
# BayesOpt-Iteration 29 - ini-Ensemblemember 3
# BayesOpt-Iteration 29 - ini-Ensemblemember 4
# BayesOpt-Iteration 29 - ini-Ensemblemember 5
# total elapsed time = 0:43:30.599136
# (pp) elapsed time = 0:43:30.599136
#
# beststep 20, current step 30
# BayesOpt-Iteration 30 - ini-Ensemblemember 1
# BayesOpt-Iteration 30 - ini-Ensemblemember 2
# BayesOpt-Iteration 30 - ini-Ensemblemember 3
# BayesOpt-Iteration 30 - ini-Ensemblemember 4
# BayesOpt-Iteration 30 - ini-Ensemblemember 5
# total elapsed time = 0:46:21.197037
# (pp) elapsed time = 0:46:21.197037
#
# beststep 20, current step 31
# BayesOpt-Iteration 31 - ini-Ensemblemember 1
# BayesOpt-Iteration 31 - ini-Ensemblemember 2
# BayesOpt-Iteration 31 - ini-Ensemblemember 3
# BayesOpt-Iteration 31 - ini-Ensemblemember 4
# BayesOpt-Iteration 31 - ini-Ensemblemember 5
# total elapsed time = 0:47:47.448629
# (pp) elapsed time = 0:47:47.448629
#
# beststep 20, current step 32
# BayesOpt-Iteration 32 - ini-Ensemblemember 1
# BayesOpt-Iteration 32 - ini-Ensemblemember 2
# BayesOpt-Iteration 32 - ini-Ensemblemember 3
# BayesOpt-Iteration 32 - ini-Ensemblemember 4
# BayesOpt-Iteration 32 - ini-Ensemblemember 5
# total elapsed time = 0:48:49.167608
# (pp) elapsed time = 0:48:49.167608
#
# beststep 20, current step 33
# BayesOpt-Iteration 33 - ini-Ensemblemember 1
# BayesOpt-Iteration 33 - ini-Ensemblemember 2
# BayesOpt-Iteration 33 - ini-Ensemblemember 3
# BayesOpt-Iteration 33 - ini-Ensemblemember 4
# BayesOpt-Iteration 33 - ini-Ensemblemember 5
# total elapsed time = 0:50:18.589560
# (pp) elapsed time = 0:50:18.589560
#
# beststep 20, current step 34
# BayesOpt-Iteration 34 - ini-Ensemblemember 1
# BayesOpt-Iteration 34 - ini-Ensemblemember 2
# BayesOpt-Iteration 34 - ini-Ensemblemember 3
# BayesOpt-Iteration 34 - ini-Ensemblemember 4
# BayesOpt-Iteration 34 - ini-Ensemblemember 5
# total elapsed time = 0:52:53.918979
# (pp) elapsed time = 0:52:53.918979
#
# beststep 20, current step 35
# BayesOpt-Iteration 35 - ini-Ensemblemember 1
# BayesOpt-Iteration 35 - ini-Ensemblemember 2
# BayesOpt-Iteration 35 - ini-Ensemblemember 3
# BayesOpt-Iteration 35 - ini-Ensemblemember 4
# BayesOpt-Iteration 35 - ini-Ensemblemember 5
# total elapsed time = 0:54:16.494635
# (pp) elapsed time = 0:54:16.494635
#
# beststep 20, current step 36
# BayesOpt-Iteration 36 - ini-Ensemblemember 1
# BayesOpt-Iteration 36 - ini-Ensemblemember 2
# BayesOpt-Iteration 36 - ini-Ensemblemember 3
# BayesOpt-Iteration 36 - ini-Ensemblemember 4
# BayesOpt-Iteration 36 - ini-Ensemblemember 5
# total elapsed time = 0:55:18.720039
# (pp) elapsed time = 0:55:18.720039
#
# beststep 20, current step 37
# BayesOpt-Iteration 37 - ini-Ensemblemember 1
# BayesOpt-Iteration 37 - ini-Ensemblemember 2
# BayesOpt-Iteration 37 - ini-Ensemblemember 3
# BayesOpt-Iteration 37 - ini-Ensemblemember 4
# BayesOpt-Iteration 37 - ini-Ensemblemember 5
# total elapsed time = 0:56:20.520907
# (pp) elapsed time = 0:56:20.520907
#
# beststep 20, current step 38
# BayesOpt-Iteration 38 - ini-Ensemblemember 1
# BayesOpt-Iteration 38 - ini-Ensemblemember 2
# BayesOpt-Iteration 38 - ini-Ensemblemember 3
# BayesOpt-Iteration 38 - ini-Ensemblemember 4
# BayesOpt-Iteration 38 - ini-Ensemblemember 5
# total elapsed time = 0:57:41.335380
# (pp) elapsed time = 0:57:41.335380
#
# beststep 20, current step 39
# BayesOpt-Iteration 39 - ini-Ensemblemember 1
# BayesOpt-Iteration 39 - ini-Ensemblemember 2
# BayesOpt-Iteration 39 - ini-Ensemblemember 3
# BayesOpt-Iteration 39 - ini-Ensemblemember 4
# BayesOpt-Iteration 39 - ini-Ensemblemember 5
# total elapsed time = 1:02:26.523408
# (pp) elapsed time = 1:02:26.523408
#
# beststep 20, current step 40
# BayesOpt-Iteration 40 - ini-Ensemblemember 1
# BayesOpt-Iteration 40 - ini-Ensemblemember 2
# BayesOpt-Iteration 40 - ini-Ensemblemember 3
# BayesOpt-Iteration 40 - ini-Ensemblemember 4
# BayesOpt-Iteration 40 - ini-Ensemblemember 5
# total elapsed time = 1:03:46.760052
# (pp) elapsed time = 1:03:46.760052
#
# beststep 20, current step 41
# BayesOpt-Iteration 41 - ini-Ensemblemember 1
# BayesOpt-Iteration 41 - ini-Ensemblemember 2
# BayesOpt-Iteration 41 - ini-Ensemblemember 3
# BayesOpt-Iteration 41 - ini-Ensemblemember 4
# BayesOpt-Iteration 41 - ini-Ensemblemember 5
# total elapsed time = 1:07:26.187910
# (pp) elapsed time = 1:07:26.188907
#
# beststep 20, current step 42
# BayesOpt-Iteration 42 - ini-Ensemblemember 1
# BayesOpt-Iteration 42 - ini-Ensemblemember 2
# BayesOpt-Iteration 42 - ini-Ensemblemember 3
# BayesOpt-Iteration 42 - ini-Ensemblemember 4
# BayesOpt-Iteration 42 - ini-Ensemblemember 5
# total elapsed time = 1:10:47.418035
# (pp) elapsed time = 1:10:47.418035
#
# beststep 20, current step 43
# BayesOpt-Iteration 43 - ini-Ensemblemember 1
# BayesOpt-Iteration 43 - ini-Ensemblemember 2
# BayesOpt-Iteration 43 - ini-Ensemblemember 3
# BayesOpt-Iteration 43 - ini-Ensemblemember 4
# BayesOpt-Iteration 43 - ini-Ensemblemember 5
# total elapsed time = 1:11:58.065094
# (pp) elapsed time = 1:11:58.065094
#
# beststep 20, current step 44
# BayesOpt-Iteration 44 - ini-Ensemblemember 1
# BayesOpt-Iteration 44 - ini-Ensemblemember 2
# BayesOpt-Iteration 44 - ini-Ensemblemember 3
# BayesOpt-Iteration 44 - ini-Ensemblemember 4
# BayesOpt-Iteration 44 - ini-Ensemblemember 5
# total elapsed time = 1:14:36.077869
# (pp) elapsed time = 1:14:36.077869
#
# beststep 20, current step 45
# BayesOpt-Iteration 45 - ini-Ensemblemember 1
# BayesOpt-Iteration 45 - ini-Ensemblemember 2
# BayesOpt-Iteration 45 - ini-Ensemblemember 3
# BayesOpt-Iteration 45 - ini-Ensemblemember 4
# BayesOpt-Iteration 45 - ini-Ensemblemember 5
# total elapsed time = 1:14:46.610506
# (pp) elapsed time = 1:14:46.610506
#
# beststep 20, current step 46
# BayesOpt-Iteration 46 - ini-Ensemblemember 1
# BayesOpt-Iteration 46 - ini-Ensemblemember 2
# BayesOpt-Iteration 46 - ini-Ensemblemember 3
# BayesOpt-Iteration 46 - ini-Ensemblemember 4
# BayesOpt-Iteration 46 - ini-Ensemblemember 5
# total elapsed time = 1:15:44.422044
# (pp) elapsed time = 1:15:44.422044
#
# beststep 20, current step 47
# BayesOpt-Iteration 47 - ini-Ensemblemember 1
# BayesOpt-Iteration 47 - ini-Ensemblemember 2
# BayesOpt-Iteration 47 - ini-Ensemblemember 3
# BayesOpt-Iteration 47 - ini-Ensemblemember 4
# BayesOpt-Iteration 47 - ini-Ensemblemember 5
# total elapsed time = 1:16:41.623457
# (pp) elapsed time = 1:16:41.623457
#
# beststep 20, current step 48
# BayesOpt-Iteration 48 - ini-Ensemblemember 1
# BayesOpt-Iteration 48 - ini-Ensemblemember 2
# BayesOpt-Iteration 48 - ini-Ensemblemember 3
# BayesOpt-Iteration 48 - ini-Ensemblemember 4
# BayesOpt-Iteration 48 - ini-Ensemblemember 5
# total elapsed time = 1:17:23.658659
# (pp) elapsed time = 1:17:23.658659
#
# beststep 20, current step 49
# BayesOpt-Iteration 49 - ini-Ensemblemember 1
# BayesOpt-Iteration 49 - ini-Ensemblemember 2
# BayesOpt-Iteration 49 - ini-Ensemblemember 3
# BayesOpt-Iteration 49 - ini-Ensemblemember 4
# BayesOpt-Iteration 49 - ini-Ensemblemember 5
# total elapsed time = 1:17:32.977641
# (pp) elapsed time = 1:17:32.977641
#
# beststep 20, current step 50
# BayesOpt-Iteration 50 - ini-Ensemblemember 1
# BayesOpt-Iteration 50 - ini-Ensemblemember 2
# BayesOpt-Iteration 50 - ini-Ensemblemember 3
# BayesOpt-Iteration 50 - ini-Ensemblemember 4
# BayesOpt-Iteration 50 - ini-Ensemblemember 5
# total elapsed time = 1:18:05.000311
# (pp) elapsed time = 1:18:05.000311
#
# beststep 20, current step 51
# BayesOpt-Iteration 51 - ini-Ensemblemember 1
# BayesOpt-Iteration 51 - ini-Ensemblemember 2
# BayesOpt-Iteration 51 - ini-Ensemblemember 3
# BayesOpt-Iteration 51 - ini-Ensemblemember 4
# BayesOpt-Iteration 51 - ini-Ensemblemember 5
# total elapsed time = 1:19:01.146553
# (pp) elapsed time = 1:19:01.146553
#
# BEST:	{'target': 1.947450658211986, 'params': {'batchsize': 20.389186562606035, 'hiddensize': 48.25909184153295}}

# %%
#run test set simulations
t1_test = datetime.datetime.now()

# %%
scores, sim_med, obs, inimax, predresults_ensembles, errors_ensembles = simulate_testset(hiddensize_int, batchsize_int)#errors(20,4)
print(predresults_ensembles.shape)
print(errors_ensembles)
# Out:
#         NSE        R2      RMSE      Bias
# 0  0.971896  0.974808  0.006196 -0.001842
# (55, 20)
# [[ 8.28752337e-01  8.51183275e-01  1.52954951e-02  1.70943430e-03]
#  [ 9.62496910e-01  9.76382622e-01  7.15788539e-03  4.35397623e-03]
#  [ 8.43789682e-01  8.73643623e-01  1.46085150e-02 -3.25765727e-03]
#  [ 9.20315977e-01  9.22346517e-01  1.04336638e-02  1.66549379e-03]
#  [ 9.55145348e-01  9.61118096e-01  7.82807464e-03 -2.80808879e-03]
#  [ 9.54626566e-01  9.84817731e-01  7.87321363e-03 -6.22316343e-03]
#  [ 8.46368276e-01  8.90161267e-01  1.44874405e-02 -7.56605845e-03]
#  [ 9.39455904e-01  9.44245732e-01  9.09467349e-03 -2.21406291e-03]
#  [ 8.88417498e-01  9.01222142e-01  1.23466535e-02 -4.16703135e-03]
#  [ 9.56578413e-01  9.56761991e-01  7.70200966e-03 -5.00159966e-04]
#  [ 9.04060488e-01  9.27670600e-01  1.14485363e-02 -4.59757209e-03]
#  [ 9.25748861e-01  9.33540983e-01  1.00716998e-02 -2.06425686e-03]
#  [ 8.74284007e-01  9.04816085e-01  1.31052852e-02 -4.90545954e-03]
#  [ 9.83662877e-01  9.83685045e-01  4.72431671e-03 -6.49863864e-05]
#  [ 8.26242477e-01  8.72000516e-01  1.54071752e-02 -2.27118858e-03]
#  [ 9.84951116e-01  9.87033748e-01  4.53422806e-03 -1.65292365e-03]
#  [ 9.64321394e-01  9.77122413e-01  6.98160303e-03  4.32108122e-04]
#  [ 9.23223339e-01  9.29143302e-01  1.02415532e-02 -2.24944043e-03]
#  [ 9.17189616e-01  9.43611037e-01  1.06363743e-02  6.00389251e-03]
#  [ 9.47636562e-01  9.57890338e-01  8.45795345e-03 -3.53185215e-03]]

# %%
t2_test = datetime.datetime.now()

# %%
f = open('./timelog_bc_c5'+'.txt', "a") 
print("Time [s] for Test-Eval(10 inis)\n{}\n".format(t2_test-t1_test), file = f)

# %%
for i in range(inimax):
    if errors_ensembles[i,0]==np.max(errors_ensembles[:,0]):
        maxi=i
NSE_best=r2_score(Y_test,predresults_ensembles[:, maxi])
print(NSE_best)
sim_best=np.asarray(predresults_ensembles[:, maxi].reshape(-1,1))#(n,1)
###print(obs, sim_med,sim_best,predresults_ensembles, errors_ensembles)
np.savetxt('sim_med_bc_c5'+'.csv',sim_med, delimiter=',')
np.savetxt('sim_best_bc_c5'+'.csv',sim_best, delimiter=',')
np.savetxt('pred_ensembles_bc_c5'+'.csv',predresults_ensembles, delimiter=',')
np.savetxt('error_ensembles_bc_c5'+'.csv',errors_ensembles, delimiter=',')
# Out:
# 0.9849511159872235

# %%
nums = range(1, len(obs) + 1)

pyplot.figure(figsize=(15,6))
pyplot.plot(nums, sim_med, 'r', label ="sim_med")
        
for ini in range(inimax):
    if ini==maxi:
        pyplot.plot(nums, predresults_ensembles[:, ini], 'black', label='sim_best', alpha=1)
    else:
        pyplot.plot(nums, predresults_ensembles[:, ini], 'r', label='_nolegend_', alpha=0.2)
        
pyplot.plot(nums, obs, 'b', label ="observed")
pyplot.title("bc_c5", size=15)
pyplot.ylabel('Concentration [g/L]', size=12)
pyplot.xlabel('Time [s]',size=12)
pyplot.legend(fontsize=12,bbox_to_anchor=(1, 1),loc='upper right')
pyplot.tight_layout()

s = """NSE = {:.2f}\nR²  = {:.2f}\nRMSE = {:.2f}\nBias = {:.2f}\nhiddensize = {:d}\nbatchsize = {:d}""".format(scores.NSE[0],scores.R2[0],
        scores.RMSE[0],scores.Bias[0],hiddensize_int,batchsize_int)

pyplot.figtext(0.9, 0.6, s, bbox=dict(facecolor='white'))
pyplot.savefig('bc_c5.png', dpi=300)
pyplot.show()

# %%
print(scores.NSE)
# Out:
# 0    0.971896
# Name: NSE, dtype: float64

# %%
# print log summary file
f = open('./log_summary_bc_c5'+'.txt', "w", encoding= "utf-8")
print("\nBEST:\n\n"+s+"\n", file = f)
print("best iteration = {}".format(step+1), file = f)
print("max iteration = {}\n".format(len(optimizer.res)), file = f)

for i, res in enumerate(optimizer.res):
    print("Iteration {}: \t{}".format(i+1, res), file = f) 
f.close()

# %% [markdown]
# #print ensemble member errors
# np.savetxt('./errors_ensembles_abc_a5'+'.txt',errors_ensembles,delimiter=';',header = 'NSE;R²;RMSE;Bias', fmt = '%.4f', encoding= "utf-8")
#
# #print sim data
# printdf = pd.DataFrame(data=predresults_ensembles,index=nums)
# printdf.to_csv('./pred_ensembles_abc_a5'+'.txt',sep=';')
